# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
metric_df = pd.read_csv('metrics.csv')

# %%
print(list(metric_df.columns))
# Out:
# ['epoch', 'loss', 'accuracy']

# %%
plt.title('Loss')
plt.plot(metric_df['epoch'], metric_df['loss'])
plt.show()

# %%
plt.title('Accuracy')
plt.plot(metric_df['epoch'], metric_df['accuracy'])
plt.show()
